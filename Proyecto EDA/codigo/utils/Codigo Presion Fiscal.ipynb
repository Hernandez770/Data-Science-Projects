# %%
import matplotlib.pyplot as plt
import matplotlib.style as style
import matplotlib.ticker as ticker
import pandas as pd

# %%
data = pd.read_csv('../data/clean_data/presion_fiscal_clean.csv',sep = ',')

# %%
data
# Out:
#     Presion Fiscal   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0          Germany  35.01  35.70  36.39  36.76  36.70  36.99  37.42  37.79
# 1        Australia  25.60  26.27  27.12  27.33  27.32  27.92  27.60  28.50
# 2          Austria  40.83  41.02  41.97  42.82  42.71  43.10  41.91  41.76
# 3          Belgium  42.62  43.14  44.18  45.16  45.07  44.81  43.88  43.80
# 4           Canada  30.65  30.54  30.99  30.86  31.34  32.68  33.17  33.11
# 5            Chile  19.68  21.24  21.33  19.86  19.61  20.38  20.14  20.16
# 6         Colombia  18.10    NaN    NaN  20.02    NaN  19.90    NaN  18.98
# 7            Korea  23.39  24.16  24.78  24.30  24.59  25.16  26.24  25.36
# 8       Costa Rica  22.13    NaN    NaN  22.98    NaN  22.95    NaN    NaN
# 9          Denmark  45.06  45.12  45.51  45.89  48.53  46.13  45.69  45.85
# 10        Slovenia  36.90  36.48  36.87  36.75  36.19  36.35  36.51  37.13
# ...

# %%
data = data.set_index("Presion Fiscal")

# %%
data
# Out:
#                  2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# Presion Fiscal
# Germany         35.01  35.70  36.39  36.76  36.70  36.99  37.42  37.79  38.43
# Australia       25.60  26.27  27.12  27.33  27.32  27.92  27.60  28.50  28.53
# Austria         40.83  41.02  41.97  42.82  42.71  43.10  41.91  41.76  42.25
# Belgium         42.62  43.14  44.18  45.16  45.07  44.81  43.88  43.80  43.87
# Canada          30.65  30.54  30.99  30.86  31.34  32.68  33.17  33.11  33.51
# Chile           19.68  21.24  21.33  19.86  19.61  20.38  20.14  20.16  21.13
# Colombia        18.10    NaN    NaN  20.02    NaN  19.90    NaN  18.98  19.27
# Korea           23.39  24.16  24.78  24.30  24.59  25.16  26.24  25.36  26.69
# Costa Rica      22.13    NaN    NaN  22.98    NaN  22.95    NaN    NaN  23.19
# Denmark         45.06  45.12  45.51  45.89  48.53  46.13  45.69  45.85  44.18
# Slovenia        36.90  36.48  36.87  36.75  36.19  36.35  36.51  37.13  37.27
# ...

# %%
colors = [[0,0,0],[255/255,0,128/255] , [86/255,180/255,233/255], [0,158/255,115/255], [213/255,94/255,0], [0,114/255,178/255], 
          [240/255,228/255,66/255], [110/255,190/255,60/255], 
          [200/255,100/255,200/255], [128/255,128/255,128/255], [0,255/255,128/255], [230/255,159/255,0],
          [128/255,0,255/255], [255/255,128/255,0], [0,128/255,255/255], [128/255,255/255,0], [0,200/255,255/255]]

# %%
countries = ['Average OECD','Spain','Italy','Sweden','Denmark','France','United States','Ireland','Chile','Turkey']
#countries = ['Average OECD','Spain', 'Germany', 'United Kingdom', 'France', 'Italy', 'Netherlands','Poland','Sweden','Ireland']
data_countries = data.loc[data.index.isin(countries)]
style.use('fivethirtyeight')

plt.figure(figsize=(12,8))
for country, color in zip(countries, colors):
    plt.plot(data.loc[country][:], label=country, linewidth=2.5, color=color)
plt.xlabel('Year')
plt.ylabel('%')
plt.title('Fiscal pressure')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))
plt.ticklabel_format(style='plain', axis='y')
plt.ylim(bottom=15, top=50)
# Out:
# (15.0, 50.0)
