# %%
import matplotlib.pyplot as plt
import matplotlib.style as style
import matplotlib.ticker as ticker
import pandas as pd

# %%
data = pd.read_csv('../data/clean_data/DEBT_EU_clean.csv',sep = ',')

# %%
data = data.set_index("Government consolidated gross debt")

# %%
data
# Out:
#                                            2002-Q1  2002-Q2  2002-Q3  2002-Q4  \
# Government consolidated gross debt
# European Union - 27 countries (from 2020)  5506467  5546619  5590396  5589363
# Euro area â 20 countries (from 2023)     5116813  5163853  5192783  5187905
# Euro area - 19 countries  (2015-2022)      5106774  5153824  5182628  5177508
# Belgium                                     295527   293733   292962   288111
# Bulgaria                                     10255     9257     9278     8890
# Czechia                                      20100    22160    23279    22013
# Denmark                                      90372    92399    96599    93174
# Germany                                    1285983  1290253  1308782  1317680
# Estonia                                        332      414      423      442
# Ireland                                      40934    41857    42853    41987
# Greece                                      161507   162757   164471   171410
# ...

# %%
#COLORS WITHOUT AVERAGE
colors = [[255/255,0,128/255] , [86/255,180/255,233/255], [0,158/255,115/255], [213/255,94/255,0], [0,114/255,178/255], 
          [240/255,228/255,66/255], [110/255,190/255,60/255], 
          [200/255,100/255,200/255], [128/255,128/255,128/255], [0,255/255,128/255], [230/255,159/255,0],
          [128/255,0,255/255], [255/255,128/255,0], [0,128/255,255/255], [128/255,255/255,0], [0,200/255,255/255]]

# %%
countries = ['Spain']
#countries = ['Spain']
data_countries = data.loc[data.index.isin(countries)]
style.use('fivethirtyeight')

plt.figure(figsize=(12,8))
for country, color in zip(countries, colors):
    plt.plot(data.loc[country][:], label=country, linewidth=2.5, color=color)
plt.xlabel('Year')
plt.xticks(rotation=-45)
plt.ylabel('million €')
plt.title('Government consolidated gross debt')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))
#plt.legend()
plt.ticklabel_format(style='plain', axis='y')
plt.axhline(y = 0, color = 'black', linewidth = 1.4, alpha = .7)
#plt.ylim(bottom=750000, top=1350000)
formatter = ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x).replace(',', '.'))
plt.gca().yaxis.set_major_formatter(formatter)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#COLORS WITHOUT AVERAGE
colors = [[255/255,0,128/255] , [86/255,180/255,233/255], [213/255,94/255,0], [0,114/255,178/255], 
          [240/255,228/255,66/255], [110/255,190/255,60/255], 
          [200/255,100/255,200/255], [128/255,128/255,128/255], [0,255/255,128/255], [230/255,159/255,0],
          [128/255,0,255/255], [255/255,128/255,0], [0,128/255,255/255], [128/255,255/255,0], [0,200/255,255/255]]
countries = ['Spain', 'Germany', 'France', 'Italy', 'Netherlands', 'Poland', 'Sweden']
#countries = ['Spain']
data_countries = data.loc[data.index.isin(countries)]
style.use('fivethirtyeight')

plt.figure(figsize=(12,8))
for country, color in zip(countries, colors):
    #plt.plot(data.loc[country][3::4], label=country, linewidth=2.5, color=color)  # only plot the 4th quarter values
    plt.plot(data.loc[country][2::4], label=country, linewidth=2.5, color=color)
plt.xlabel('Year')
plt.xticks(rotation=-45)
plt.ylabel('million €')
plt.title('Government consolidated gross debt')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))
#plt.legend()
plt.ticklabel_format(style='plain', axis='y')
plt.axhline(y = 0, color = 'black', linewidth = 1.4, alpha = .7)
#plt.ylim(bottom=750000, top=1350000)
formatter = ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x).replace(',', '.'))
plt.gca().yaxis.set_major_formatter(formatter)
plt.show()

# %%
for country, color in zip(countries, colors):
    country_data = data.loc[country][3::4].tolist()  # only plot the 4th quarter values
    country_data.append(data.loc[country]['2022-Q3'])  # append the value of 2022-Q3
    plt.plot(country_data, label=country, linewidth=2.5, color=color)

# %%
countries = ['Spain', 'Germany', 'France', 'Italy', 'Netherlands', 'Poland', 'Sweden']
#countries = ['Spain']
data_countries = data.loc[data.index.isin(countries)]
style.use('fivethirtyeight')

plt.figure(figsize=(12,8))
for country, color in zip(countries, colors):
    country_data = data.loc[country][3::4].tolist()  # only plot the 4th quarter values
    country_data.append(data.loc[country]['2022-Q3'])  # append the value of 2022-Q3
    plt.plot(country_data, label=country, linewidth=2.5, color=color)
plt.xlabel('Year')
plt.xticks(rotation=-45)
plt.ylabel('million €')
plt.title('Government consolidated gross debt')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))
#plt.legend()
plt.ticklabel_format(style='plain', axis='y')
plt.axhline(y = 0, color = 'black', linewidth = 1.4, alpha = .7)
#plt.ylim(bottom=750000, top=1350000)
formatter = ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x).replace(',', '.'))
plt.gca().yaxis.set_major_formatter(formatter)
plt.show()

# %%
countries = ['Spain', 'Germany', 'France', 'Italy', 'Netherlands', 'Poland', 'Sweden']
#countries = ['Spain']
data_countries = data.loc[data.index.isin(countries)]
style.use('fivethirtyeight')

plt.figure(figsize=(12,8))
for country, color in zip(countries, colors):
    plt.plot(data.loc[country].iloc[:, 3:-1].values.flatten(), label=country, linewidth=2.5, color=color)
plt.xlabel('Year')
plt.xticks(ticks=range(0, len(data.columns[3:-1]), 4), labels=data.columns[3:-1:4], rotation=-45)
plt.ylabel('million €')
plt.title('Government consolidated gross debt')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))
#plt.legend()
plt.ticklabel_format(style='plain', axis='y')
plt.axhline(y=0, color='black', linewidth=1.4, alpha=.7)
#plt.ylim(bottom=750000, top=1350000)
formatter = ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x).replace(',', '.'))
plt.gca().yaxis.set_major_formatter(formatter)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[31], line 8
#       6 plt.figure(figsize=(12,8))
#       7 for country, color in zip(countries, colors):
# ----> 8     plt.plot(data.loc[country].iloc[:, 3:-1].values.flatten(), label=country, linewidth=2.5, color=color)
#       9 plt.xlabel('Year')
#      10 plt.xticks(ticks=range(0, len(data.columns[3:-1]), 4), labels=data.columns[3:-1:4], rotation=-45)
#
# File ~/opt/anaconda3/envs/eda_envi/lib/python3.10/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# ...

# %%
countries = ['Spain', 'Germany', 'France', 'Italy', 'Netherlands', 'Poland', 'Sweden']
data_countries = data.loc[countries]
data_countries_q4 = data_countries.iloc[:, 3::4]  # select every 4th column, starting from the 4th

style.use('fivethirtyeight')
plt.figure(figsize=(12,8))

for country, color in zip(countries, colors):
    plt.plot(data_countries_q4.loc[country], label=country, linewidth=2.5, color=color)

plt.xlabel('Year')
plt.xticks(rotation=-45)
plt.ylabel('million €')
plt.title('Government consolidated gross debt')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))
plt.ticklabel_format(style='plain', axis='y')
plt.axhline(y=0, color='black', linewidth=1.4, alpha=.7)
formatter = ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x).replace(',', '.'))
plt.gca().yaxis.set_major_formatter(formatter)
plt.show()
