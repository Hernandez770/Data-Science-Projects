# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('../../data/dirty_data/employment.csv',sep = ';', encoding='latin',decimal=",")

# %%
data
# Out:
#                    Total employment(domestic concept)        2002        2003  \
# 0           European Union - 27 countries (from 2020)  188.400,10  188.965,03
# 1           European Union - 28 countries (2013-2020)  216.344,00  217.188,10
# 2           European Union - 15 countries (1995-2004)  172.852,05  173.608,11
# 3   Euro area (EA11-1999, EA12-2001, EA13-2007, EA...  137.779,74  138.306,79
# 4                Euro area Ð 20 countries (from 2023)  145.715,04  146.358,89
# 5               Euro area - 19 countries  (2015-2022)  144.166,28  144.773,32
# 6                Euro area - 12 countries (2001-2006)  137.779,74  138.306,79
# 7                                             Belgium    4.175,50    4.171,60
# 8                                            Bulgaria    3.222,12    3.317,39
# 9                                             Czechia    4.876,77    4.838,06
# 10                                            Denmark    2.784,20    2.758,65
# ...

# %%
data.replace(':', pd.np.nan, inplace=True)
# Out:
# /var/folders/6_/c1yy797x7w7g6g9sl3c4rqmw0000gn/T/ipykernel_2400/2430488528.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   data.replace(':', pd.np.nan, inplace=True)

# %%
data = data.set_index('Total employment(domestic concept)')

# %%
for col in data.columns:
    data[col] = data[col].str.split(',', expand=True)[0].str.replace('\.', '')
# Out:
# /var/folders/6_/c1yy797x7w7g6g9sl3c4rqmw0000gn/T/ipykernel_2400/1936806075.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data[col] = data[col].str.split(',', expand=True)[0].str.replace('\.', '')

# %%
data = data.dropna(axis=0)

# %%
data
# Out:
#                                                       2002    2003    2004  \
# Total employment(domestic concept)
# European Union - 27 countries (from 2020)           188400  188965  189831
# Euro area (EA11-1999, EA12-2001, EA13-2007, EA1...  137779  138306  139404
# Euro area Ð 20 countries (from 2023)                145715  146358  147465
# Euro area - 19 countries  (2015-2022)               144166  144773  145867
# Euro area - 12 countries (2001-2006)                137779  138306  139404
# Belgium                                               4175    4171    4212
# Bulgaria                                              3222    3317    3403
# Czechia                                               4876    4838    4828
# Denmark                                               2784    2758    2744
# Germany (until 1990 former territory of the FRG)     39666   39237   39362
# Estonia                                                588     601     598
# ...

# %%
data= data.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, European Union - 27 countries (from 2020) to Switzerland
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2002    35 non-null     int64
#  1   2003    35 non-null     int64
#  2   2004    35 non-null     int64
#  3   2005    35 non-null     int64
#  4   2006    35 non-null     int64
#  5   2007    35 non-null     int64
#  6   2008    35 non-null     int64
#  7   2009    35 non-null     int64
#  8   2010    35 non-null     int64
#  9   2011    35 non-null     int64
#  10  2012    35 non-null     int64
#  11  2013    35 non-null     int64
#  12  2014    35 non-null     int64
#  13  2015    35 non-null     int64
#  14  2016    35 non-null     int64
#  15  2017    35 non-null     int64
#  16  2018    35 non-null     int64
#  17  2019    35 non-null     int64
#  18  2020    35 non-null     int64
#  19  2021    35 non-null     int64
# ...

# %%
data.to_csv('employment_clean.csv')
