# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
RGDP_growth =pd.read_csv('../../data/dirty_data/RGDP_growth.csv',sep = ';',index_col=0, encoding='latin',decimal=',')

# %%
RGDP_growth = RGDP_growth.replace(',','.', regex=True)

# %%
RGDP_growth.replace(':', pd.np.nan, inplace=True)
# Out:
# /var/folders/6_/c1yy797x7w7g6g9sl3c4rqmw0000gn/T/ipykernel_2780/783706526.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   RGDP_growth.replace(':', pd.np.nan, inplace=True)

# %%
RGDP_growth = RGDP_growth.astype(float)

# %%
RGDP_growth.index =RGDP_growth.index.str.replace(r'ï»¿Real GDP Growth', 'Real GDP Growth', regex=True)

# %%
RGDP_growth = RGDP_growth.drop('Bosnia and Herzegovina')

# %%
RGDP_growth
# Out:
#                                                     2011  2012  2013  2014  \
# ï»¿Real GDP Growth
# Germany (until 1990 former territory of the FRG)     3.9   0.4   0.4   2.2
# Norway                                               1.1   2.7   1.0   2.0
# Serbia                                               2.0  -0.7   2.9  -1.6
# Belgium                                              1.7   0.7   0.5   1.6
# Finland                                              2.5  -1.4  -0.9  -0.4
# Portugal                                            -1.7  -4.1  -0.9   0.8
# Bulgaria                                             2.1   0.8  -0.6   1.0
# Denmark                                              1.3   0.2   0.9   1.6
# Lithuania                                            6.0   3.8   3.6   3.5
# Luxembourg                                           1.0   1.6   3.2   2.6
# Croatia                                             -0.1  -2.3  -0.4  -0.4
# ...

# %%
RGDP_growth.to_csv('RGDP_growth_clean.csv')
