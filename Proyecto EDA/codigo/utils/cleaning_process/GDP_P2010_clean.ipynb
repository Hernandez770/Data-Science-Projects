# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
GDP_P2010= pd.read_csv('../../data/dirty_data/GDP_P2010.csv',sep = ';', encoding='latin')

# %%
GDP_P2010.head()
# Out:
#                                           GDP(P2010)          2002  \
# 0          European Union - 27 countries (from 2020)   9.926.285,6
# 1          European Union - 28 countries (2013-2020)  11.597.764,5
# 2          European Union - 15 countries (1995-2004)  10.808.195,3
# 3  Euro area (EA11-1999, EA12-2001, EA13-2007, EA...   8.599.611,7
# 4               Euro area Ð 20 countries (from 2023)   8.788.546,7
#
#            2003          2004          2005          2006          2007  \
# 0  10.011.712,6  10.264.759,7  10.457.471,2  10.819.409,0  11.158.294,5
# 1  11.749.279,6  12.041.382,2  12.290.136,9  12.698.941,1  13.079.468,6
# 2  10.932.470,9  11.185.354,0  11.397.336,2  11.753.280,9  12.077.961,5
# 3   8.649.331,7   8.842.452,8   8.983.095,2   9.266.021,7   9.570.723,8
# 4   8.846.970,2   9.049.120,0   9.200.551,9   9.497.462,8   9.782.006,0
#
#            2008          2009          2010  ...          2013          2014  \
# ...

# %%
GDP_P2010
# Out:
#                                            GDP(P2010)          2002  \
# 0           European Union - 27 countries (from 2020)   9.926.285,6
# 1           European Union - 28 countries (2013-2020)  11.597.764,5
# 2           European Union - 15 countries (1995-2004)  10.808.195,3
# 3   Euro area (EA11-1999, EA12-2001, EA13-2007, EA...   8.599.611,7
# 4                Euro area Ð 20 countries (from 2023)   8.788.546,7
# 5               Euro area - 19 countries  (2015-2022)   8.749.156,2
# 6                Euro area - 12 countries (2001-2006)   8.599.611,7
# 7                                             Belgium     315.079,1
# 8                                            Bulgaria      26.890,4
# 9                                             Czechia     120.708,2
# 10                                            Denmark     228.124,1
# 11   Germany (until 1990 former territory of the FRG)   2.389.573,6
# 12                                            Estonia      11.953,6
# ...

# %%
GDP_P2010.replace(':', pd.np.nan, inplace=True)
# Out:
# /var/folders/6_/c1yy797x7w7g6g9sl3c4rqmw0000gn/T/ipykernel_74746/427617056.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   GDP_P2010.replace(':', pd.np.nan, inplace=True)

# %%
GDP_P2010
# Out:
#                                            GDP(P2010)          2002  \
# 0           European Union - 27 countries (from 2020)   9.926.285,6
# 1           European Union - 28 countries (2013-2020)  11.597.764,5
# 2           European Union - 15 countries (1995-2004)  10.808.195,3
# 3   Euro area (EA11-1999, EA12-2001, EA13-2007, EA...   8.599.611,7
# 4                Euro area Ð 20 countries (from 2023)   8.788.546,7
# 5               Euro area - 19 countries  (2015-2022)   8.749.156,2
# 6                Euro area - 12 countries (2001-2006)   8.599.611,7
# 7                                             Belgium     315.079,1
# 8                                            Bulgaria      26.890,4
# 9                                             Czechia     120.708,2
# 10                                            Denmark     228.124,1
# 11   Germany (until 1990 former territory of the FRG)   2.389.573,6
# 12                                            Estonia      11.953,6
# ...

# %%
GDP_P2010
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 GDP_P2010
#
# NameError: name 'GDP_P2010' is not defined

# %%
GDP_P2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GDP(P2010)  43 non-null     object
#  1   2002        42 non-null     object
#  2   2003        42 non-null     object
#  3   2004        42 non-null     object
#  4   2005        42 non-null     object
#  5   2006        43 non-null     object
#  6   2007        43 non-null     object
#  7   2008        43 non-null     object
#  8   2009        43 non-null     object
#  9   2010        43 non-null     object
#  10  2011        43 non-null     object
#  11  2012        43 non-null     object
#  12  2013        43 non-null     object
#  13  2014        43 non-null     object
#  14  2015        43 non-null     object
#  15  2016        43 non-null     object
#  16  2017        43 non-null     object
#  17  2018        43 non-null     object
#  18  2019        43 non-null     object
# ...

# %%
#Convertir todos los valores a float menos la primera columna (ya que me sirve de index)
for col in GDP_P2010.columns[1]:
    GDP_P2010[col] = GDP_P2010[col].str.replace(".", "").str.replace(",", ".").astype(float)
# Out:
#   Cell In[19], line 2
#     for col in GDP_P2010.columns[1]
#                                    ^
# SyntaxError: expected ':'

# %%
GDP_P2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GDP(P2010)  43 non-null     object
#  1   2002        42 non-null     float64
#  2   2003        42 non-null     float64
#  3   2004        42 non-null     float64
#  4   2005        42 non-null     float64
#  5   2006        43 non-null     float64
#  6   2007        43 non-null     float64
#  7   2008        43 non-null     float64
#  8   2009        43 non-null     float64
#  9   2010        43 non-null     float64
#  10  2011        43 non-null     float64
#  11  2012        43 non-null     float64
#  12  2013        43 non-null     float64
#  13  2014        43 non-null     float64
#  14  2015        43 non-null     float64
#  15  2016        43 non-null     float64
#  16  2017        43 non-null     float64
#  17  2018        43 non-null     float64
# ...

# %%
GDP_P2010.iloc[:, 0] = GDP_P2010.iloc[:, 0].astype(str)

# %%
GDP_P2010.to_csv('GDP_P2010_clean.csv')
