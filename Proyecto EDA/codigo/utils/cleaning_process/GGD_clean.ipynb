# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
GGD= pd.read_csv('../../data/dirty_data/General_gov_debt.csv',sep = ';',index_col=0, encoding='latin',decimal=',')

# %%
GGD
# Out:
#                                                  1950        1951  \
# General Government Debt (Percent of GDP)
# Albania                                       no data     no data
# Australia                                     no data     no data
# Austria                                       no data     no data
# Belarus                                       no data     no data
# Belgium                                       no data     no data
# ...                                               ...         ...
# United States                             83,12603738  72,9550324
# Uzbekistan                                    no data     no data
# Venezuela                                     no data     no data
# Vietnam                                       no data     no data
# Yemen                                         no data     no data
#
#                                                  1952         1953  \
# General Government Debt (Percent of GDP)
# ...

# %%
GGD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88 entries, Albania to Yemen
# Data columns (total 72 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1950    88 non-null     object
#  1   1951    88 non-null     object
#  2   1952    88 non-null     object
#  3   1953    88 non-null     object
#  4   1954    88 non-null     object
#  5   1955    88 non-null     object
#  6   1956    88 non-null     object
#  7   1957    88 non-null     object
#  8   1958    88 non-null     object
#  9   1959    88 non-null     object
#  10  1960    88 non-null     object
#  11  1961    88 non-null     object
#  12  1962    88 non-null     object
#  13  1963    88 non-null     object
#  14  1964    88 non-null     object
#  15  1965    88 non-null     object
#  16  1966    88 non-null     object
#  17  1967    88 non-null     object
#  18  1968    88 non-null     object
#  19  1969    88 non-null     object
#  20  1970    88 non-null     object
# ...

# %%
GGD.replace('no data', pd.np.nan, inplace=True)
# Out:
# /var/folders/6_/c1yy797x7w7g6g9sl3c4rqmw0000gn/T/ipykernel_1549/1778020221.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   GGD.replace('no data', pd.np.nan, inplace=True)

# %%
GGD
# Out:
#                                                  1950        1951  \
# General Government Debt (Percent of GDP)
# Albania                                           NaN         NaN
# Australia                                         NaN         NaN
# Austria                                           NaN         NaN
# Belarus                                           NaN         NaN
# Belgium                                           NaN         NaN
# ...                                               ...         ...
# United States                             83,12603738  72,9550324
# Uzbekistan                                        NaN         NaN
# Venezuela                                         NaN         NaN
# Vietnam                                           NaN         NaN
# Yemen                                             NaN         NaN
#
#                                                  1952         1953  \
# General Government Debt (Percent of GDP)
# ...

# %%
GGD.index.name
# Out:
# 'General Government Debt (Percent of GDP)'

# %%
GGD.drop(GGD.iloc[:, 0:1],inplace=True, axis=1)

# %%
GGD
# Out:
#                                                 2001        2002        2003  \
# General Government Debt (Percent of GDP)
# Albania                                    60.612782   64.096916   60.244562
# Australia                                  17.132308   15.024551   13.191327
# Austria                                    66.354554   66.977797   64.896277
# Belarus                                          NaN         NaN         NaN
# Belgium                                   108.216846  105.436680  101.659311
# ...                                              ...         ...         ...
# United States                              53.146247   55.537858   58.624539
# Uzbekistan                                 44.838459   41.632893   31.412345
# Venezuela                                  30.728852   48.176668   56.028999
# Vietnam                                    25.420214   27.711371   29.835244
# Yemen                                      60.568578   57.827228   56.823012
#
# ...

# %%
GGD.plot( y='2020', kind='line');

# %%
GGD = GGD.replace(',','.', regex=True)

# %%
GGD
# Out:
#                                                 2000        2001        2002  \
# General Government Debt (Percent of GDP)
# Albania                                    63.768684   60.612782   64.096916
# Australia                                  19.525999   17.132308   15.024551
# Austria                                    65.737618   66.354554   66.977797
# Belarus                                          NaN         NaN         NaN
# Belgium                                   109.589041  108.216846  105.436680
# ...                                              ...         ...         ...
# United States                              53.169404   53.146247   55.537858
# Uzbekistan                                 29.478736   44.838459   41.632893
# Venezuela                                  27.700467   30.728852   48.176668
# Vietnam                                    24.754757   25.420214   27.711371
# Yemen                                      60.840745   60.568578   57.827228
#
# ...

# %%
GGD = GGD.astype(float)

# %%
GGD.dropna(inplace=True)

# %%
GGD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, Albania to Yemen
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2001    80 non-null     float64
#  1   2002    80 non-null     float64
#  2   2003    80 non-null     float64
#  3   2004    80 non-null     float64
#  4   2005    80 non-null     float64
#  5   2006    80 non-null     float64
#  6   2007    80 non-null     float64
#  7   2008    80 non-null     float64
#  8   2009    80 non-null     float64
#  9   2010    80 non-null     float64
#  10  2011    80 non-null     float64
#  11  2012    80 non-null     float64
#  12  2013    80 non-null     float64
#  13  2014    80 non-null     float64
#  14  2015    80 non-null     float64
#  15  2016    80 non-null     float64
#  16  2017    80 non-null     float64
#  17  2018    80 non-null     float64
#  18  2019    80 non-null     float64
#  19  2020    80 non-null     float64
# ...

# %%
GGD.to_csv('GGD_clean.csv')
