# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../../data/dirty_data/deficit_surplus.csv',sep = ';',encoding='latin',decimal=',')

# %%
data = data.set_index('ï»¿General Government Deficit Surplus')

# %%
data = data.astype(float)

# %%
data
# Out:
#                                        2010  2011  2012  2013  2014  2015  \
# ï»¿General Government Deficit Surplus
# Denmark                                -2.7  -2.1  -3.5  -1.2   1.1  -1.2
# Luxembourg                             -0.3   0.7   0.5   0.8   1.3   1.3
# Bulgaria                               -3.7  -1.7  -0.8  -0.7  -5.4  -1.9
# Netherlands                            -5.3  -4.4  -3.9  -3.0  -2.3  -1.9
# Germany                                -4.4  -0.9   0.0   0.0   0.6   1.0
# Cyprus                                 -4.7  -5.7  -5.7  -5.6  -8.8  -0.9
# Greece                                -11.4 -10.5  -9.1 -13.4  -3.7  -5.9
# Malta                                  -2.2  -3.0  -3.4  -2.2  -1.5  -0.8
# Austria                                -4.4  -2.6  -2.2  -2.0  -2.7  -1.0
# Slovenia                               -5.6  -6.6  -4.0 -14.6  -5.5  -2.8
# Sweden                                 -0.1  -0.3  -1.1  -1.5  -1.5   0.0
# ...

# %%
data.to_csv('deficit_surplus_clean.csv')
