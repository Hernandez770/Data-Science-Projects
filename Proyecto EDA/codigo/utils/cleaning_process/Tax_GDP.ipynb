# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tax_GDP =pd.read_csv('../../data/dirty_data/Tax_GDP.csv',sep = ';',index_col=0, encoding='latin',decimal=',')

# %%
tax_GDP = tax_GDP.replace(',','.', regex=True)

# %%
tax_GDP.replace('..', pd.np.nan, inplace=True)
# Out:
# /var/folders/6_/c1yy797x7w7g6g9sl3c4rqmw0000gn/T/ipykernel_2316/2840235904.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   tax_GDP.replace('..', pd.np.nan, inplace=True)

# %%
tax_GDP = tax_GDP.astype(float)

# %%
tax_GDP.index =tax_GDP.index.str.replace(r'Belg+¨ca', 'Belgica', regex=True)

# %%
tax_GDP
# Out:
#                 2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  \
# ï»¿Tax to GDP
# Alemania        35.0  35.7  36.4  36.8  36.7  37.0  37.4  37.8  38.4  38.6
# Australia       25.6  26.3  27.1  27.3  27.3  27.9  27.6  28.5  28.5  27.7
# Austria         40.8  41.0  42.0  42.8  42.7  43.1  41.9  41.8  42.3  42.6
# Belgica         42.6  43.1  44.2  45.2  45.1  44.8  43.9  43.8  43.9  42.7
# Canada          30.6  30.5  31.0  30.9  31.3  32.7  33.2  33.1  33.5  33.8
# Chile           19.7  21.2  21.3  19.9  19.6  20.4  20.1  20.2  21.1  20.9
# Colombia        18.1   NaN   NaN  20.0   NaN  19.9   NaN  19.0  19.3  19.7
# Corea           23.4  24.2  24.8  24.3  24.6  25.2  26.2  25.4  26.7  27.3
# Costa Rica      22.1   NaN   NaN  23.0   NaN  22.9   NaN   NaN  23.2  23.6
# Dinamarca       45.1  45.1  45.5  45.9  48.5  46.1  45.7  45.8  44.2  46.6
# Eslovenia       36.9  36.5  36.9  36.7  36.2  36.4  36.5  37.1  37.3  37.2
# ...

# %%
tax_GDP.to_csv('Tax_GDP_clean.csv')
