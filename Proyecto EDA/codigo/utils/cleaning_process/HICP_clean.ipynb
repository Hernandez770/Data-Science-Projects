# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
HICP =pd.read_csv('../../data/dirty_data/HICP.csv',sep = ';',index_col=0, encoding='latin',decimal=',')

# %%
HICP = HICP.drop('Euro area â 20 countries (from 2023)')

# %%
HICP
# Out:
#                                                     2011  2012  2013  2014  \
# ï»¿HICP - Inflation rate
# European Union (EU6-1958, EU9-1973, EU10-1981, ...   3.1   2.6   1.5   0.6
# European Union - 27 countries (from 2020)            2.9   2.6   1.3   0.4
# European Union - 28 countries (2013-2020)            3.1   2.6   1.5   0.6
# Euro area (EA11-1999, EA12-2001, EA13-2007, EA1...   2.7   2.5   1.4   0.4
# Euro area - 19 countries  (2015-2022)                2.7   2.5   1.3   0.4
# Belgium                                              3.4   2.6   1.2   0.5
# Bulgaria                                             3.4   2.4   0.4  -1.6
# Czechia                                              2.2   3.5   1.4   0.4
# Denmark                                              2.7   2.4   0.5   0.4
# Germany (until 1990 former territory of the FRG)     2.5   2.2   1.6   0.8
# Estonia                                              5.1   4.2   3.2   0.5
# ...

# %%
HICP.replace(':', pd.np.nan, inplace=True)
# Out:
# /var/folders/6_/c1yy797x7w7g6g9sl3c4rqmw0000gn/T/ipykernel_1361/3634854320.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   HICP.replace(':', pd.np.nan, inplace=True)

# %%
HICP.drop(HICP.tail(1).index,inplace=True)

# %%
HICP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, European Union (EU6-1958, EU9-1973, EU10-1981, EU12-1986, EU15-1995, EU25-2004, EU27-2007, EU28-2013, EU27-2020) to Serbia
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2011    38 non-null     float64
#  1   2012    38 non-null     float64
#  2   2013    38 non-null     float64
#  3   2014    38 non-null     float64
#  4   2015    38 non-null     float64
#  5   2016    38 non-null     float64
#  6   2017    38 non-null     float64
#  7   2018    38 non-null     float64
#  8   2019    38 non-null     float64
#  9   2020    36 non-null     float64
#  10  2021    36 non-null     float64
#  11  2022    36 non-null     float64
# dtypes: float64(12)
# memory usage: 3.9+ KB

# %%
HICP = HICP.replace(',','.', regex=True)

# %%
HICP = HICP.astype(float)

# %%
HICP.to_csv('HICP_clean.csv')
