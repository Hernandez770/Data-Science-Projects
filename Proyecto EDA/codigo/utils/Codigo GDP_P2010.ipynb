# %%
import matplotlib.pyplot as plt
import matplotlib.style as style
import matplotlib.ticker as ticker
import pandas as pd

# %%
data = pd.read_csv('../data/clean_data/GDP_P2010_clean.csv',sep = ';')

# %%
data = data.set_index("GDP(P2010)")

# %%
data = data.fillna(0)

# %%
data = data.round().astype(int)

# %%
data
# Out:
#                                                         2002      2003  \
# GDP(P2010)
# European Union - 27 countries (from 2020)            9926286  10011713
# European Union - 28 countries (2013-2020)           11597764  11749280
# European Union - 15 countries (1995-2004)           10808195  10932471
# Euro area (EA11-1999, EA12-2001, EA13-2007, EA1...   8599612   8649332
# Euro area Ã 20 countries (from 2023)                8788547   8846970
# Euro area - 19 countries  (2015-2022)                8749156   8805685
# Euro area - 12 countries (2001-2006)                 8599612   8649332
# Belgium                                               315079    318350
# Bulgaria                                               26890     28299
# Czechia                                               120708    125034
# Denmark                                               228124    229014
# Germany                                              2389574   2372844
# ...

# %%
#COLORS WITHOUT AVERAGE
colors = [[255/255,0,128/255] , [86/255,180/255,233/255], [0,158/255,115/255], [213/255,94/255,0], [0,114/255,178/255], 
          [240/255,228/255,66/255], [110/255,190/255,60/255], 
          [200/255,100/255,200/255], [128/255,128/255,128/255], [0,255/255,128/255], [230/255,159/255,0],
          [128/255,0,255/255], [255/255,128/255,0], [0,128/255,255/255], [128/255,255/255,0], [0,200/255,255/255]]

# %%
countries = ['Spain','Italy','France','Germany']

# %%
data_countries = data.loc[data.index.isin(countries)]
style.use('fivethirtyeight')

plt.figure(figsize=(12,8))
for country, color in zip(countries, colors):
    plt.plot(data.loc[country][:], label=country, linewidth=2.5, color=color)
plt.xlabel('Year')
plt.xticks(rotation=-45)
plt.ylabel('million €')
plt.title('GDP (constant prices 2010)')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1))
#plt.legend(loc='upper left')
plt.ticklabel_format(style='plain', axis='y')
plt.axhline(y = 0, color = 'black', linewidth = 1.4, alpha = .7)
plt.ylim(bottom=750000,top=1350000)
formatter = ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x).replace(',', '.'))
plt.gca().yaxis.set_major_formatter(formatter)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
countries = ['Spain']

data_countries = data.loc[data.index.isin(countries)]
style.use('fivethirtyeight')

plt.figure(figsize=(12,8))
for country, color in zip(countries, colors):
    plt.plot(data.loc[country][1:], label=country, linewidth=2.5, color=color)
plt.xlabel('Año')
plt.xticks(rotation=-45)
plt.ylabel('GDP')
plt.title('GDP (Prices 2010)')
plt.legend()
plt.ticklabel_format(style='plain', axis='y')
plt.axhline(y = 0, color = 'black', linewidth = 1.4, alpha = .7)
plt.ylim(bottom=750000)
formatter = ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x).replace(',', '.'))
plt.gca().yaxis.set_major_formatter(formatter)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
